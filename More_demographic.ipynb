# %%
dbutils.fs.ls("/FileStore/tables")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: [FileInfo(path=&#39;dbfs:/FileStore/tables/demographic_info/&#39;, name=&#39;demographic_info/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/multicsvfile/&#39;, name=&#39;multicsvfile/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/small/&#39;, name=&#39;small/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/weather/&#39;, name=&#39;weather/&#39;, size=0)]</div>

# %%
dbutils.fs.mkdirs("/FileStore/tables/small/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>

# %%
from pyspark.sql.types import StringType, StructType, StructField, FloatType, TimestampType, IntegerType, DateType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_schema = StructType([StructField('LCLid', StringType(), True),
                       StructField('tstp', TimestampType(), True),
                       StructField('energy(kWh/hh)', FloatType(), True),])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.csv("dbfs:/FileStore/tables/small", header = True, schema = df_schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_demo = spark.read.csv("/FileStore/tables/demographic_info/informations_households.csv", header = True, inferSchema = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_acorn = spark.read.csv("/FileStore/tables/demographic_info/acorn_details.csv", header = True, inferSchema = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_join = df.join(df_demo, 'LCLid')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_join.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LCLid</th><th>tstp</th><th>energy(kWh/hh)</th><th>stdorToU</th><th>Acorn</th><th>Acorn_grouped</th><th>file</th></tr></thead><tbody><tr><td>MAC000048</td><td>2011-12-08T12:30:00.000+0000</td><td>0.229</td><td>ToU</td><td>ACORN-E</td><td>Affluent</td><td>block_20</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:00:00.000+0000</td><td>0.213</td><td>ToU</td><td>ACORN-E</td><td>Affluent</td><td>block_20</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:30:00.000+0000</td><td>0.272</td><td>ToU</td><td>ACORN-E</td><td>Affluent</td><td>block_20</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:00:00.000+0000</td><td>0.576</td><td>ToU</td><td>ACORN-E</td><td>Affluent</td><td>block_20</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:30:00.000+0000</td><td>0.194</td><td>ToU</td><td>ACORN-E</td><td>Affluent</td><td>block_20</td></tr></tbody></table></div>

# %%
df_avg_group = df_join.select('LCLid','tstp', 'Acorn', 'file', 'energy(kWh/hh)').groupBy('Acorn').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import unix_timestamp, from_unixtime, date_format
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_time = df_join.select(df_join.LCLid, df_join.tstp, df_join.Acorn, df_join.file, df_join['energy(kWh/hh)'], unix_timestamp(df_join.tstp, 'm/d/yyyy h:m:ss a').alias('ut'))\
  .select(df_join.LCLid, df_join.tstp, df_join.Acorn, df_join.file, df_join['energy(kWh/hh)'], from_unixtime('ut').alias('dty'))\
  .select(df_join.LCLid, df_join.tstp, df_join.Acorn, df_join.file, df_join['energy(kWh/hh)'], date_format('dty', 'd/M/yyyy').alias('Date'),
          date_format('dty', 'hh:mm:ss a').alias('Time'),
          date_format('dty', 'M').alias('Month'),
          date_format('dty', 'HH').alias('Hour'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_energy = df.select('tstp', 'energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df
# %%
df1=df_time.withColumn("Month", df_time["Month"].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import floor, col
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df1.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LCLid</th><th>tstp</th><th>Acorn</th><th>file</th><th>energy(kWh/hh)</th><th>Date</th><th>Time</th><th>Month</th></tr></thead><tbody><tr><td>MAC000048</td><td>2011-12-08T12:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.229</td><td>8/12/2011</td><td>12:30:0 PM</td><td>12</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:00:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.213</td><td>8/12/2011</td><td>1:0:0 PM</td><td>12</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.272</td><td>8/12/2011</td><td>1:30:0 PM</td><td>12</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:00:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.576</td><td>8/12/2011</td><td>2:0:0 PM</td><td>12</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.194</td><td>8/12/2011</td><td>2:30:0 PM</td><td>12</td></tr></tbody></table></div>

# %%
df_month = df1.withColumn('season', floor(df1['Month']%12/3)+1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_month.select('Month', 'season').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
display(df_month.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LCLid</th><th>tstp</th><th>Acorn</th><th>file</th><th>energy(kWh/hh)</th><th>Date</th><th>Time</th><th>Month</th><th>season</th></tr></thead><tbody><tr><td>MAC000048</td><td>2011-12-08T12:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.229</td><td>8/12/2011</td><td>12:30:0 PM</td><td>12</td><td>1</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:00:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.213</td><td>8/12/2011</td><td>1:0:0 PM</td><td>12</td><td>1</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.272</td><td>8/12/2011</td><td>1:30:0 PM</td><td>12</td><td>1</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:00:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>0.576</td><td>8/12/2011</td><td>2:0:0 PM</td><td>12</td><td>1</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:30:00.000+0000</td><td>ACORN
# %%
df_season_group = df_month.select('LCLid', 'Acorn', 'file', 'energy(kWh/hh)', 'season').groupBy('season', 'Acorn').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_season_group.orderBy('avg(energy(kWh/hh))', ascending=False).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>Acorn</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>1</td><td>ACORN-A</td><td>0.3045786590237697</td></tr><tr><td>1</td><td>ACORN-D</td><td>0.30454144874379174</td></tr><tr><td>1</td><td>ACORN-E</td><td>0.30450504813981527</td></tr><tr><td>1</td><td>ACORN-B</td><td>0.3043634373545845</td></tr><tr><td>1</td><td>ACORN-C</td><td>0.3043106753618357</td></tr><tr><td>1</td><td>ACORN-</td><td>0.30152956516759555</td></tr><tr><td>2</td><td>ACORN-C</td><td>0.25755310593916186</td></tr><tr><td>2</td><td>ACORN-B</td><td>0.2574648376795319</td></tr><tr><td>2</td><td>ACORN-A</td><td>0.25741206230373376</td></tr><tr><td>2</td><td>ACORN-D</td><td>0.2554588490627925</td></tr><tr><td>2</td><td>ACORN-E</td><td>0.25522123601730584</td></tr><tr><td>4</td><td>ACORN-B</td><td>0.2519856629267085</td></tr><tr><td>4</td><td>ACORN-C</td><td>0.25129384847729636</td></tr><tr><td>4</td><td>ACORN-A</td><td>0.25119021929325464</td></tr><tr><td>4</td><td>ACORN-</td><td>0.25100655469823946</td></tr><tr><td>4</td><td>ACORN-E</td><td>0.2493063360224417</td></tr><tr><td>4</td><td>ACORN-D</td><td>0.24926843366169196</td></tr><tr><td>2</td><td>ACORN-</td><td>0.2216043666917479</td></tr><tr><td>3</td><td>ACORN-</td><td>0.19606156715298395</td></tr><tr><td>3</td><td>ACORN-D</td><td>0.19444990531319878</td></tr></tbody></table></div>

# %%
  df_avg_time = df_time.select('LCLid', 'Time', 'Acorn', 'file', 'energy(kWh/hh)').filter(df_time.Acorn.isin(acron_list)).groupBy('Time', 'Acorn').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_avg_time.orderBy('avg(energy(kWh/hh))', ascending=False).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Time</th><th>Acorn</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>7:30:0 PM</td><td>ACORN-B</td><td>0.3965887249143358</td></tr><tr><td>7:30:0 PM</td><td>ACORN-C</td><td>0.39516883289342697</td></tr><tr><td>7:30:0 PM</td><td>ACORN-A</td><td>0.39438126082623554</td></tr><tr><td>7:0:0 PM</td><td>ACORN-B</td><td>0.3937058410013068</td></tr><tr><td>7:0:0 PM</td><td>ACORN-C</td><td>0.3922678979757604</td></tr><tr><td>7:0:0 PM</td><td>ACORN-A</td><td>0.39140747733071485</td></tr><tr><td>8:0:0 PM</td><td>ACORN-B</td><td>0.39088243387713384</td></tr><tr><td>8:0:0 PM</td><td>ACORN-C</td><td>0.3895329596247594</td></tr><tr><td>8:0:0 PM</td><td>ACORN-A</td><td>0.3888568027667886</td></tr><tr><td>7:30:0 PM</td><td>ACORN-D</td><td>0.388444113457976</td></tr><tr><td>6:30:0 PM</td><td>ACORN-B</td><td>0.3858990517365163</td></tr><tr><td>7:0:0 PM</td><td>ACORN-D</td><td>0.3852509711232017</td></tr><tr><td>6:30:0 PM</td><td>ACORN-C</td><td>0.3844994981171446</td></tr><tr><td>6:30:0 PM</td><td>ACORN-A</td><td>0.383609537224698</td></tr><tr><td>8:0:0 PM</td><td>ACORN-D</td><td>0.38332932171652895</td></tr><tr><td>8:30:0 PM</td><td>ACORN-B</td><td>0.38187667208752885</td></tr><tr><td>8:30:0 PM</td><td>ACORN-C</td><td>0.38063998946927613</td></tr><tr><td>8:30:0 PM</td><td>ACORN-A</td><td>0.380061765295745</td></tr><tr><td>6:30:0 PM</td><td>ACORN-D</td><td>0.3775566986982222</td></tr><tr><td>8:30:0 PM</td><td>ACORN-D</td><td>0.375045860501041</td></tr></tbody></table></div>

# %%
df_season_group = df_month.select('LCLid', 'season', 'Acorn', 'file', 'energy(kWh/hh)').filter(df_month.Acorn.isin('ACORN-A')).groupBy('season').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_season_group.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>1</td><td>0.4666186416339891</td></tr><tr><td>3</td><td>0.3214046511153585</td></tr><tr><td>2</td><td>0.3957909567904761</td></tr><tr><td>4</td><td>0.3962565700511204</td></tr></tbody></table></div>

# %%
df_season_group1 = df_month.select('LCLid', 'season', 'Acorn', 'file', 'energy(kWh/hh)').filter(df_month.Acorn.isin('ACORN-B')).groupBy('season').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_season_group1.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>1</td><td>0.2914630538945395</td></tr><tr><td>3</td><td>0.19497872137794114</td></tr><tr><td>2</td><td>0.23374792216802417</td></tr><tr><td>4</td><td>0.2576486139470246</td></tr></tbody></table></div>

# %%
df_season_group2 = df_month.select('LCLid', 'season', 'Acorn', 'file', 'energy(kWh/hh)').filter(df_month.Acorn.isin('ACORN-C')).groupBy('season').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_season_group2.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>1</td><td>0.2917705490680019</td></tr><tr><td>3</td><td>0.20658731459355836</td></tr><tr><td>2</td><td>0.2420574012171795</td></tr><tr><td>4</td><td>0.24698125510527566</td></tr></tbody></table></div>

# %%
df_season_group3 = df_month.select('LCLid', 'season', 'Acorn', 'file', 'energy(kWh/hh)').where(df_month.Acorn =='ACORN-D').groupBy('season').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_season_group3.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>1</td><td>0.30454144874379174</td></tr><tr><td>3</td><td>0.19444990531319878</td></tr><tr><td>2</td><td>0.2554588490627925</td></tr><tr><td>4</td><td>0.24926843366169196</td></tr></tbody></table></div>

# %%
df2=df_time.withColumn("Hour", df_time["Hour"].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_day = df2.withColumn('session', floor((df2['Hour']%24)/8))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_day_group = df_day.select('LCLid', 'session', 'Acorn', 'Hour', 'energy(kWh/hh)').where(df_day.Acorn =='ACORN-A').groupBy('session').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_day_group.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>session</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>0</td><td>0.2590322206868792</td></tr><tr><td>1</td><td>0.404928334928941</td></tr><tr><td>2</td><td>0.5325448655786358</td></tr></tbody></table></div>

# %%
df_day.select('Hour', 'session').distinct().orderBy('Hour', ascending=False).show(24)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+
# Hour|session|
# +----+-------+
#   23|      2|
#   22|      2|
#   21|      2|
#   20|      2|
#   19|      2|
#   18|      2|
#   17|      2|
#   16|      2|
#   15|      1|
#   14|      1|
#   13|      1|
#   12|      1|
#   11|      1|
#   10|      1|
#    9|      1|
#    8|      1|
#    7|      0|
#    6|      0|
#    5|      0|
#    4|      0|
#    3|      0|
#    2|      0|
#    1|      0|
#    0|      0|
# +----+-------+
#
# </div>

# %%
df_day_group1 = df_day.select('LCLid', 'session', 'Acorn', 'Hour', 'energy(kWh/hh)').where(df_day.Acorn =='ACORN-B').groupBy('session').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_day_group1.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>session</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>0</td><td>0.15226746650426767</td></tr><tr><td>1</td><td>0.25508364964043767</td></tr><tr><td>2</td><td>0.3393421544867317</td></tr></tbody></table></div>

# %%
df_day_group2 = df_day.select('LCLid', 'session', 'Acorn', 'Hour', 'energy(kWh/hh)').where(df_day.Acorn =='ACORN-C').groupBy('session').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_day_group2.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>session</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>0</td><td>0.151662367980092</td></tr><tr><td>1</td><td>0.2586630446428107</td></tr><tr><td>2</td><td>0.3391704104488147</td></tr></tbody></table></div>

# %%
df_day_group3 = df_day.select('LCLid', 'session', 'Acorn', 'Hour', 'energy(kWh/hh)').where(df_day.Acorn =='ACORN-D').groupBy('session').avg('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_day_group3.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>session</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>0</td><td>0.17491417103577428</td></tr><tr><td>1</td><td>0.2896678062235594</td></tr><tr><td>2</td><td>0.38724185335529593</td></tr></tbody></table></div>

# %%
df_day = df3.withColumn('session', replace({0: 'Night', 2: 'Day', 3: 'Evening'}, inplace=True))
