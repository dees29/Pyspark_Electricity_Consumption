# %%
dbutils.fs.ls("/FileStore/tables")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [FileInfo(path=&#39;dbfs:/FileStore/tables/demographic_info/&#39;, name=&#39;demographic_info/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/multicsvfile/&#39;, name=&#39;multicsvfile/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/weather/&#39;, name=&#39;weather/&#39;, size=0)]</div>

# %%
dbutils.fs.mkdirs("/FileStore/tables/small/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: True</div>

# %%
dbutils.fs.mkdirs("/FileStore/tables/small/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %fs cp /tmp/test_dbfs.txt /tmp/file_b.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.types import StringType, StructType, StructField, FloatType, TimestampType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_schema = StructType([StructField('LCLid', StringType(), True),
                       StructField('tstp', TimestampType(), True),
                       StructField('energy(kWh/hh)', FloatType(), True),])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.csv("dbfs:/FileStore/tables/multicsvfile", header = True, schema = df_schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LCLid</th><th>tstp</th><th>energy(kWh/hh)</th></tr></thead><tbody><tr><td>MAC000048</td><td>2011-12-08T12:30:00.000+0000</td><td>0.229</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:00:00.000+0000</td><td>0.213</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:30:00.000+0000</td><td>0.272</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:00:00.000+0000</td><td>0.576</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:30:00.000+0000</td><td>0.194</td></tr></tbody></table></div>

# %%
df_demo = spark.read.csv("/FileStore/tables/demographic_info/informations_households.csv", header = True, inferSchema = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_demo.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LCLid</th><th>stdorToU</th><th>Acorn</th><th>Acorn_grouped</th><th>file</th></tr></thead><tbody><tr><td>MAC005492</td><td>ToU</td><td>ACORN-</td><td>ACORN-</td><td>block_0</td></tr><tr><td>MAC001074</td><td>ToU</td><td>ACORN-</td><td>ACORN-</td><td>block_0</td></tr><tr><td>MAC000002</td><td>Std</td><td>ACORN-A</td><td>Affluent</td><td>block_0</td></tr><tr><td>MAC003613</td><td>Std</td><td>ACORN-A</td><td>Affluent</td><td>block_0</td></tr><tr><td>MAC003597</td><td>Std</td><td>ACORN-A</td><td>Affluent</td><td>block_0</td></tr></tbody></table></div>

# %%
df_acorn = spark.read.csv("/FileStore/tables/demographic_info/acorn_details.csv", header = True, inferSchema = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_acorn.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MAIN CATEGORIES</th><th>CATEGORIES</th><th>REFERENCE</th><th>ACORN-A</th><th>ACORN-B</th><th>ACORN-C</th><th>ACORN-D</th><th>ACORN-E</th><th>ACORN-F</th><th>ACORN-G</th><th>ACORN-H</th><th>ACORN-I</th><th>ACORN-J</th><th>ACORN-K</th><th>ACORN-L</th><th>ACORN-M</th><th>ACORN-N</th><th>ACORN-O</th><th>ACORN-P</th><th>ACORN-Q</th></tr></thead><tbody><tr><td>POPULATION</td><td>Age</td><td>Age 0-4</td><td>77.0</

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_avg_group.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Acorn</th><th>avg(energy(kWh/hh))</th></tr></thead><tbody><tr><td>ACORN-E</td><td>0.2165012154761052</td></tr><tr><td>ACORN-F</td><td>0.1922656915408575</td></tr><tr><td>ACORN-Q</td><td>0.1608302613311604</td></tr><tr><td>ACORN-P</td><td>0.13834988763941491</td></tr><tr><td>ACORN-D</td><td>0.28398738046651395</td></tr><tr><td>ACORN-K</td><td>0.2094371546716786</td></tr><tr><td>ACORN-H</td><td>0.23021328068465718</td></tr><tr><td>ACORN-J</td><td>0.23746680368285097</td></tr><tr><td>ACORN-N</td><td>0.19294199595311862</td></tr><tr><td>ACORN-A</td><td>0.3989048712841816</td></tr><tr><td>ACORN-L</td><td>0.20970308237526203</td></tr><tr><td>ACORN-G</td><td>0.2126265814725709</td></tr><tr><td>ACORN-C</td><td>0.24987959010271366</td></tr><tr><td>ACORN-O</td><td>0.17889032648114697</td></tr><tr><td>ACORN-M</td><td>0.20893658727729522</td></tr><tr><td>ACORN-I</td><td>0.19743245573242174</td></tr><tr><td>ACORN-B</td><td>0.24894816908846315</td></tr><tr><td>ACORN-</td><td>0.2516223898474334</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import unix_timestamp, from_unixtime, date_format
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_time = df_join.select(df_join.LCLid, df_join.tstp, df_join.Acorn, df_join.file, unix_timestamp(df_join.tstp, 'm/d/yyyy h:m:ss a').alias('ut'))\
  .select(df_join.LCLid, df_join.tstp, df_join.Acorn, df_join.file, from_unixtime('ut').alias('dty'))\
  .select(df_join.LCLid, df_join.tstp, df_join.Acorn, df_join.file, date_format('dty', 'd/M/yyyy').alias('Date'),
          date_format('dty', 'h:m:s a').alias('Time'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_time.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LCLid</th><th>tstp</th><th>Acorn</th><th>file</th><th>Date</th><th>Time</th></tr></thead><tbody><tr><td>MAC000048</td><td>2011-12-08T12:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>8/12/2011</td><td>12:30:0 PM</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:00:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>8/12/2011</td><td>1:0:0 PM</td></tr><tr><td>MAC000048</td><td>2011-12-08T13:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>8/12/2011</td><td>1:30:0 PM</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:00:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>8/12/2011</td><td>2:0:0 PM</td></tr><tr><td>MAC000048</td><td>2011-12-08T14:30:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>8/12/2011</td><td>2:30:0 PM</td></tr><tr><td>MAC000048</td><td>2011-12-08T15:00:00.000+0000</td><td>ACORN-E</td><td>block_20</td><td>8/12/2011</td><td>

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LCLid</th><th>Acorn</th><th>file</th><th>Date</th><th>Time</th><th>energy(kWh/hh)</th></tr></thead><tbody><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.225</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.049</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.066</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.19</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.174</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.29</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.054</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.474</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.39</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.286</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.15</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.027</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.137</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.557</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.066</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.314</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.029</td></tr><tr><td>MAC000145</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.073</td></tr><tr><td>MAC000148</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.225</td></tr><tr><td>MAC000148</td><td>ACORN-F</td><td>block_47</td><td>24/11/2011</td><td>11:0:0 AM</td><td>0.049</td></tr></tbody></table></div>

# %%
df_datetime.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df_sum_group = df_datetime.select('LCLid', 'Date', 'Acorn', 'file', 'energy(kWh/hh)').groupBy('Date', 'Acorn').sum('energy(kWh/hh)')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_sum_group.limit(20))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: Row(LCLid=&#39;MAC000048&#39;, tstp=datetime.datetime(2011, 12, 8, 12, 30), energy(kWh/hh)=0.2290000021457672)</div>
